# %% [markdown]
# # Combining DataFrames With Pandas - Lab
#
# ## Introduction
#
# In this lab, you'll gain practice combining DataFrames through concatenation.  You'll also practice executing various types of joins to selectively combine the information stored in the tables!
#
# ## Objectives
#
# In this lab you will:
#
# - Use concatenation to combine DataFrames
# - Determine which type of join is preferred for two tables of data and a task
# - Use different types of joins to merge dataframes
#
#
# ## Concatenating DataFrames
#
# Run the cell below to create some sample DataFrames for us to work with.

# %%
import pandas as pd
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                    index=[0, 1, 2, 3])


df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                    index=[4, 5, 6, 7])

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'], 
                    'D': ['D8', 'D9', 'D10', 'D11']},
                    index=[8, 9, 10, 11])

# %% [markdown]
# Now that you have multiple DataFrames to work with, you can execute a concatenation to join them together.
#
# In the cell below, concatenate the 3 DataFrames together using the appropriate function.

# %%
combined_df = pd.concat([df1, df2, df3])
combined_df
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src="images/er1.png">
#
# ## Setting join conditions with concatenation
#
# You can also specify if the concatenation is an **_Outer Join_** or an **_Inner Join_**.  Next, you'll execute an inner join. Before you do, you need to create another table that contains some overlapping index values with a DataFrame that already exists.
#
# Run the cell below to create the new DataFrame.

# %%
df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                    'D': ['D2', 'D3', 'D6', 'D7'],
                    'F': ['F2', 'F3', 'F6', 'F7']},
                    index=[2, 3, 6, 7])

# %% [markdown]
# Now, in the cell below, use the `pd.concat()` function to join DataFrames 1 and 4.  However, this time, specify that the `join` is `'inner'`, and `axis=1`.

# %%
df1_and_4 = pd.concat([df1, df4], join='inner', axis=1)
#df1_and_4 = pd.concat([df1, df4], sort=False)  # just wanted to try this

df1_and_4
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src='images/er2.png'>
#
# You'll notice that in this case, the results contain only the rows with indexes that exist in both tables -- rows 2 and 3.  The resulting table contains the values for each column in both tables for the rows.
#
# Note that there are many, many ways that you can make full use of the `pd.concat()` function in pandas to join DataFrames together -- these are just a few of the most common examples pulled from the pandas documentation on the subject. For a full view of all the ways you can use `pd.concat()`, see the [pandas documentation](http://pandas.pydata.org/pandas-docs/stable/merging.html)!
#
# ## Load data
# Now, it's time to move on to working with the Hearthstone cards database.  This database contains information on cards from the popular game, [Hearthstone](https://playhearthstone.com/en-us/)! For full information on the dataset, see the [Kaggle page](https://www.kaggle.com/jeradrose/hearthstone-cards) for this dataset.
#
# This database consists of the following tables:
#
# * _cards_
# * *dust_costs*
# * _entourages_
# * _mechanics_
# * *play_requirements*
#
# Many of rows in each table -- but not all -- correspond to the same cards. As such, each table contains a column called `card_id` which acts as a **_Primary Key_** for each table.  You'll make use of these keys to **_join_** the different tables together into a single DataFrame. You'll also experiment with different types of joins to help us decide exactly what information you wish to combine.
#
# Simply run the cell below to import the tables from the database as DataFrames.

# %%
cards_df = pd.read_csv('cards.csv')
dust_df = pd.read_csv('dust.csv')
entourages_df = pd.read_csv('entourages.csv')
mechanics_df = pd.read_csv('mechanics.csv')
play_requirements_df = pd.read_csv('play_requirements.csv')

# %% [markdown]
# Great.  Now, let's set the correct column, `card_id`, as the index column for each of these tables, and then display each to ensure that everything is as expected.
#
# For each of the DataFrames you created in the cell above, call the `.set_index()` method and pass in `card_id`.  Also set `inplace=True`.  Then, display the `.head()` of each respective DataFrame to ensure everything worked.
#
# **_NOTE:_** Since you are performing this operation in place, running any cell a second time will result in pandas throwing an error.  If you need to run something a second time, restart the kernel using the jupyter notebook menu at the top of the page.

# %%
cards_df.set_index('card_id', inplace=True)  # inplace changes it
cards_df.head()
# Out:
#            player_class    type                name      set  \
# card_id
# KARA_00_07         MAGE   SPELL       Astral Portal     KARA
# NEW1_008a         DRUID   SPELL   Ancient Teachings  EXPERT1
# BRM_010t2         DRUID  MINION  Druid of the Flame      BRM
# AT_132          NEUTRAL  MINION  Justicar Trueheart      TGT
# OG_141          NEUTRAL  MINION   Faceless Behemoth       OG
#
#                                                          text  cost  attack  \
# card_id
# KARA_00_07           Summon a random <b>Legendary</b> minion.   1.0     NaN
# NEW1_008a                                        Draw a card.   0.0     NaN
# BRM_010t2                                                 NaN   3.0     2.0
# AT_132      <b>Battlecry:</b> Replace your starting Hero P...   6.0     6.0
# OG_141                                                    NaN  10.0    10.0
#
#             health     rarity  collectible  \
# card_id
# KARA_00_07     NaN        NaN          NaN
# NEW1_008a      NaN        NaN          NaN
# BRM_010t2      5.0     COMMON          NaN
# AT_132         3.0  LEGENDARY          1.0
# OG_141        10.0     COMMON          1.0
#
#                                                        flavor   race  \
# card_id
# KARA_00_07                                                NaN    NaN
# NEW1_008a                                                 NaN    NaN
# BRM_010t2                                                 NaN  BEAST
# AT_132      It's like putting racing stripes and a giant s...    NaN
# OG_141      Rejected names: Forty-Foot Faceless, Big ol' N...    NaN
#
#            how_to_earn how_to_earn_golden targeting_arrow_text faction  \
# card_id
# KARA_00_07         NaN                NaN                  NaN     NaN
# NEW1_008a          NaN                NaN                  NaN     NaN
# BRM_010t2          NaN                NaN                  NaN     NaN
# AT_132             NaN                NaN                  NaN     NaN
# OG_141             NaN                NaN                  NaN     NaN
#
#             durability
# card_id
# KARA_00_07         NaN
# NEW1_008a          NaN
# BRM_010t2          NaN
# AT_132             NaN
# OG_141             NaN

# %%
dust_df.set_index('card_id', inplace=True)
dust_df.head()
# Out:
#                       action  cost
# card_id
# BRM_010t2    CRAFTING_NORMAL    40
# BRM_010t2    CRAFTING_GOLDEN   400
# BRM_010t2  DISENCHANT_NORMAL     5
# BRM_010t2  DISENCHANT_GOLDEN    50
# AT_132       CRAFTING_NORMAL  1600

# %%
entourages_df.set_index('card_id', inplace=True)
entourages_df.head()
# Out:
#            entourage_card_id
# card_id
# KAR_A10_22        KAR_A10_09
# KAR_A10_22        KAR_A10_02
# KAR_A10_22        KAR_A10_08
# KAR_A10_22        KAR_A10_04
# KAR_A10_22        KAR_A10_05

# %%
mechanics_df.set_index('card_id', inplace=True)
mechanics_df.head()
# Out:
#                      mechanic
# card_id
# AT_132              BATTLECRY
# GVG_011a  TAG_ONE_TURN_EFFECT
# EX1_583             BATTLECRY
# LOE_007t            EVIL_GLOW
# LOE_007t   ImmuneToSpellpower

# %%
play_requirements_df.set_index('card_id', inplace=True)
play_requirements_df.head()
# Out:
#                      play_requirement  value
# card_id
# KARA_00_07       REQ_NUM_MINION_SLOTS      1
# PRO_001a         REQ_NUM_MINION_SLOTS      1
# NAX1_01          REQ_NUM_MINION_SLOTS      1
# DS1h_292_H1           REQ_STEADY_SHOT      0
# DS1h_292_H1  REQ_MINION_OR_ENEMY_HERO      0

# %% [markdown]
# ## Executing Joins
#
# Now that you have the tables loaded correctly, we're going to execute some joins. There are four different kinds of joins, which can best be visualized with Venn diagrams:
#
# <img src='images/Image_198_joins.png'>
#
# In these diagrams, each circle represents a DataFrame or SQL Table. The left table is the table you are working with, and the right table is the table you want to join to the table you are working with. You'll start by executing the most common type of join, an **_Inner Join_**.
#
# In the cell below, join `cards_df` with `mechanics_df` using the built-in `.join()` method on the `cards_df` object.
#
# Pass in the following parameters:
# * the table you want to join with, `mechanics_df`
# * The `how` parameter set to the type of join you want, `'inner'`

# %%
cards_with_mechanics_df = cards_df.join(mechanics_df, how='inner')
# could also use >>>> pd.concat([cards_df, mechanics_df], join='inner', axis=1)
cards_with_mechanics_df.head(50)
# Out:
#          player_class         type                    name  set  \
# card_id
# AT_002           MAGE        SPELL                  Effigy  TGT
# AT_005t       NEUTRAL       MINION                    Boar  TGT
# AT_006           MAGE       MINION        Dalaran Aspirant  TGT
# AT_007           MAGE       MINION            Spellslinger  TGT
# AT_009           MAGE       MINION                  Rhonin  TGT
# AT_010         HUNTER       MINION            Ram Wrangler  TGT
# AT_011e       NEUTRAL  ENCHANTMENT        Light's Blessing  TGT
# AT_012         PRIEST       MINION        Spawn of Shadows  TGT
# AT_017        NEUTRAL       MINION       Twilight Guardian  TGT
# AT_018         PRIEST       MINION     Confessor Paletress  TGT
# AT_019        WARLOCK       MINION              Dreadsteed  TGT
# AT_022        WARLOCK        SPELL        Fist of Jaraxxus  TGT
# AT_023        WARLOCK       MINION            Void Crusher  TGT
# AT_028          ROGUE       MINION         Shado-Pan Rider  TGT
# AT_030          ROGUE       MINION       Undercity Valiant  TGT
# AT_032          ROGUE       MINION            Shady Dealer  TGT
# AT_035t         ROGUE        SPELL                 Ambush!  TGT
# AT_036          ROGUE       MINION               Anub'arak  TGT
# AT_037          DRUID        SPELL            Living Roots  TGT
# AT_038          DRUID       MINION      Darnassus Aspirant  TGT
# AT_038          DRUID       MINION      Darnassus Aspirant  TGT
# AT_039          DRUID       MINION        Savage Combatant  TGT
# AT_039e         DRUID  ENCHANTMENT                  Savage  TGT
# AT_040          DRUID       MINION              Wildwalker  TGT
# AT_042          DRUID       MINION      Druid of the Saber  TGT
# AT_042t         DRUID       MINION         Sabertooth Lion  TGT
# AT_042t2        DRUID       MINION      Sabertooth Panther  TGT
# AT_045          DRUID       MINION                  Aviana  TGT
# AT_046         SHAMAN       MINION         Tuskarr Totemic  TGT
# AT_047         SHAMAN       MINION     Draenei Totemcarver  TGT
# AT_049         SHAMAN       MINION   Thunder Bluff Valiant  TGT
# AT_050         SHAMAN       WEAPON          Charged Hammer  TGT
# AT_054         SHAMAN       MINION          The Mistcaller  TGT
# AT_057         HUNTER       MINION            Stablemaster  TGT
# AT_057o        HUNTER  ENCHANTMENT                 Groomed  TGT
# AT_058         HUNTER       MINION            King's Elekk  TGT
# AT_059         HUNTER       MINION            Brave Archer  TGT
# AT_060         HUNTER        SPELL               Bear Trap  TGT
# AT_061e        HUNTER  ENCHANTMENT           Lock and Load  TGT
# AT_065        WARRIOR       WEAPON         King's Defender  TGT
# AT_066        WARRIOR       MINION      Orgrimmar Aspirant  TGT
# AT_069        WARRIOR       MINION        Sparring Partner  TGT
# AT_069        WARRIOR       MINION        Sparring Partner  TGT
# AT_070        NEUTRAL       MINION          Skycap'n Kragg  TGT
# AT_071        WARRIOR       MINION  Alexstrasza's Champion  TGT
# AT_072        WARRIOR       MINION            Varian Wrynn  TGT
# AT_073        PALADIN        SPELL      Competitive Spirit  TGT
# AT_075        PALADIN       MINION        Warhorse Trainer  TGT
# AT_076        PALADIN       MINION           Murloc Knight  TGT
# AT_077        PALADIN       WEAPON            Argent Lance  TGT
#
#                                                        text  cost  attack  \
# card_id
# AT_002    <b>Secret:</b> When a friendly minion dies, su...   3.0     NaN
# AT_005t                                       <b>Charge</b>   3.0     4.0
# AT_006         <b>Inspire:</b> Gain <b>Spell Damage +1</b>.   4.0     3.0
# AT_007    <b>Battlecry:</b> Add a random spell to each p...   3.0     3.0
# AT_009    <b>Deathrattle:</b> Add 3 copies of Arcane Mis...   8.0     7.0
# AT_010    <b>Battlecry:</b> If you have a Beast, summon ...   5.0     3.0
# AT_011e                                   Increased Attack.   NaN     NaN
# AT_012          <b>Inspire:</b> Deal 4 damage to each hero.   4.0     5.0
# AT_017    <b>Battlecry:</b> If you're holding a Dragon, ...   4.0     2.0
# AT_018    <b>Inspire:</b> Summon a random <b>Legendary</...   7.0     5.0
# AT_019             <b>Deathrattle:</b> Summon a Dreadsteed.   4.0     1.0
# AT_022    When you play or discard this, deal $4 damage ...   4.0     NaN
# AT_023    <b>Inspire:</b> Destroy a random minion for ea...   6.0     5.0
# AT_028                        <b>Combo:</b> Gain +3 Attack.   5.0     3.0
# AT_030                         <b>Combo:</b> Deal 1 damage.   2.0     3.0
# AT_032    <b>Battlecry:</b> If you have a Pirate, gain +...   3.0     4.0
# AT_035t   When you draw this, summon a 4/4 Nerubian for ...   0.0     NaN
# AT_036    <b>Deathrattle:</b> Return this to your hand a...   9.0     8.0
# AT_037    <b>Choose One -</b> Deal $2 damage; or Summon ...   1.0     NaN
# AT_038    <b>Battlecry:</b> Gain an empty Mana Crystal.\...   2.0     2.0
# AT_038    <b>Battlecry:</b> Gain an empty Mana Crystal.\...   2.0     2.0
# AT_039    <b>Inspire:</b> Give your hero\n+2 Attack this...   4.0     5.0
# AT_039e                                +2 Attack this turn.   NaN     NaN
# AT_040    <b>Battlecry:</b> Give a friendly Beast +3 Hea...   4.0     4.0
# AT_042    <b>Choose One -</b> Transform to gain <b>Charg...   2.0     2.0
# AT_042t                                       <b>Charge</b>   2.0     2.0
# AT_042t2                                     <b>Stealth</b>   2.0     3.0
# AT_045                               Your minions cost (1).   9.0     5.0
# AT_046       <b>Battlecry:</b> Summon a random basic Totem.   3.0     3.0
# AT_047    <b>Battlecry:</b> Gain +1/+1 for each friendly...   4.0     4.0
# AT_049          <b>Inspire:</b> Give your Totems +2 Attack.   5.0     3.0
# AT_050    <b>Deathrattle:</b> Your Hero Power becomes 'D...   4.0     2.0
# AT_054    <b>Battlecry:</b> Give all minions in your han...   6.0     4.0
# AT_057    <b>Battlecry:</b> Give a friendly Beast <b>Imm...   3.0     4.0
# AT_057o                            <b>Immune</b> this turn.   NaN     NaN
# AT_058    <b>Battlecry:</b> Reveal a minion in each deck...   2.0     3.0
# AT_059    <b>Inspire:</b> If your hand is empty, deal 2 ...   1.0     2.0
# AT_060    <b>Secret:</b> After your hero is attacked, su...   2.0     NaN
# AT_061e                                                 NaN   NaN     NaN
# AT_065    <b>Battlecry:</b> If you have a minion with <b...   3.0     3.0
# AT_066          <b>Inspire:</b> Give your weapon +1 Attack.   3.0     3.0
# AT_069    <b>Taunt</b>\n<b>Battlecry:</b> Give a\nminion...   2.0     3.0
# AT_069    <b>Taunt</b>\n<b>Battlecry:</b> Give a\nminion...   2.0     3.0
# AT_070    <b>Charrrrrge</b>\nCosts (1) less for each fri...   7.0     4.0
# AT_071    <b>Battlecry:</b> If you're holding a Dragon, ...   2.0     2.0
# AT_072    <b>Battlecry:</b> Draw 3 cards.\nPut any minio...  10.0     7.0
# AT_073    <b>Secret:</b> When your turn starts, give you...   1.0     NaN
# AT_075            Your Silver Hand Recruits have +1 Attack.   3.0     2.0
# AT_076              <b>Inspire:</b> Summon a random Murloc.   4.0     3.0
# AT_077    <b>Battlecry:</b> Reveal a minion in each deck...   2.0     2.0
#
#           health     rarity  collectible  \
# card_id
# AT_002       NaN       RARE          1.0
# AT_005t      2.0        NaN          NaN
# AT_006       5.0     COMMON          1.0
# AT_007       4.0     COMMON          1.0
# AT_009       7.0  LEGENDARY          1.0
# AT_010       3.0       RARE          1.0
# AT_011e      NaN        NaN          NaN
# AT_012       4.0       RARE          1.0
# AT_017       6.0       EPIC          1.0
# AT_018       4.0  LEGENDARY          1.0
# AT_019       1.0       EPIC          1.0
# AT_022       NaN       RARE          1.0
# AT_023       4.0       RARE          1.0
# AT_028       7.0     COMMON          1.0
# AT_030       2.0     COMMON          1.0
# AT_032       3.0       RARE          1.0
# AT_035t      NaN        NaN          NaN
# AT_036       4.0  LEGENDARY          1.0
# AT_037       NaN     COMMON          1.0
# AT_038       3.0       RARE          1.0
# AT_038       3.0       RARE          1.0
# AT_039       4.0       RARE          1.0
# AT_039e      NaN        NaN          NaN
# AT_040       4.0     COMMON          1.0
# AT_042       1.0     COMMON          1.0
# AT_042t      1.0     COMMON          NaN
# AT_042t2     2.0     COMMON          NaN
# AT_045       5.0  LEGENDARY          1.0
# AT_046       2.0     COMMON          1.0
# AT_047       4.0       RARE          1.0
# AT_049       6.0       RARE          1.0
# AT_050       NaN       EPIC          1.0
# AT_054       4.0  LEGENDARY          1.0
# AT_057       2.0       EPIC          1.0
# AT_057o      NaN        NaN          NaN
# AT_058       2.0     COMMON          1.0
# AT_059       1.0     COMMON          1.0
# AT_060       NaN     COMMON          1.0
# AT_061e      NaN        NaN          NaN
# AT_065       NaN       RARE          1.0
# AT_066       3.0     COMMON          1.0
# AT_069       2.0       RARE          1.0
# AT_069       2.0       RARE          1.0
# AT_070       6.0  LEGENDARY          1.0
# AT_071       3.0       RARE          1.0
# AT_072       7.0  LEGENDARY          1.0
# AT_073       NaN       RARE          1.0
# AT_075       4.0     COMMON          1.0
# AT_076       4.0     COMMON          1.0
# AT_077       NaN       RARE          1.0
#
#                                                      flavor    race  \
# card_id
# AT_002                                   Burning man, brah.     NaN
# AT_005t                                                 NaN   BEAST
# AT_006     Is he aspiring or inspiring?  Make up your mind!     NaN
# AT_007    Does he sling spells, or do his spells linger ...     NaN
# AT_009                               A masterless shamurai.     NaN
# AT_010       Not getting trampled is really the trick here.     NaN
# AT_011e                                                 NaN     NaN
# AT_012    What did you expect to happen?  He's a Spawn. ...     NaN
# AT_017    A result of magical experiments carried out by...  DRAGON
# AT_018    She sees into your past and makes you face you...     NaN
# AT_019    Crescendo himself summoned this steed, riding ...   DEMON
# AT_022                       * Not actually Jaraxxus' fist.     NaN
# AT_023                        We like to call him "Wesley".   DEMON
# AT_028    He needed a break after that business in the V...     NaN
# AT_030    Almost went to play for Stormwind before signi...     NaN
# AT_032    I have great deal for you... for 4 damage to y...     NaN
# AT_035t                                                 NaN     NaN
# AT_036    Was actually a pretty nice guy before, you kno...     NaN
# AT_037    2 out of 2 saplings recommend that you summon ...     NaN
# AT_038    She loves mana crystals, she hates mana crysta...     NaN
# AT_038    She loves mana crystals, she hates mana crysta...     NaN
# AT_039    Maybe if you whistle a tune it will soothe him...   BEAST
# AT_039e                                                 NaN     NaN
# AT_040    She was born to be something.  She is just not...     NaN
# AT_042    That's saberTEETH, not like curved pirate blad...     NaN
# AT_042t                                                 NaN   BEAST
# AT_042t2                                                NaN   BEAST
# AT_045    Call her "Tweety".  She'll find it real funny....     NaN
# AT_046    Turns out the tuskarr aren't real choosy about...     NaN
# AT_047    It's nice to find a real craftsman in this day...     NaN
# AT_049    Allowing totems to attack is not cheating.  I ...     NaN
# AT_050           You can only pick it up if you are worthy.     NaN
# AT_054    Calling the mist doesn't sound all that great....     NaN
# AT_057    Takes way better care of her pets than her bro...     NaN
# AT_057o                                                 NaN     NaN
# AT_058                           Elekk jousting is AWESOME.   BEAST
# AT_059              This is a "bearly" concealed reference.     NaN
# AT_060    You'll never guess what's in that conveniently...     NaN
# AT_061e                                                 NaN     NaN
# AT_065          "King's Attacker" is a shield.  Funny, huh?     NaN
# AT_066    "Four out of three orcs struggle with math." -...     NaN
# AT_069                                     Come at me, bro.     NaN
# AT_069                                     Come at me, bro.     NaN
# AT_070    What's more boss than riding a parrot with a j...  PIRATE
# AT_071    "Put more spikes on her.  No, more spikes.  Wh...     NaN
# AT_072    Leader of the Alliance!  Father of Anduin!  Al...     NaN
# AT_073    Competition can be an inspiration to improve o...     NaN
# AT_075    He doesn't even get Sundays off.  Every day he...     NaN
# AT_076              Hee hee!  Look at his cute little feet.  MURLOC
# AT_077    The stripes make it look like a candy cane, bu...     NaN
#
#          how_to_earn how_to_earn_golden            targeting_arrow_text  \
# card_id
# AT_002           NaN                NaN                             NaN
# AT_005t          NaN                NaN                             NaN
# AT_006           NaN                NaN                             NaN
# AT_007           NaN                NaN                             NaN
# AT_009           NaN                NaN                             NaN
# AT_010           NaN                NaN                             NaN
# AT_011e          NaN                NaN                             NaN
# AT_012           NaN                NaN                             NaN
# AT_017           NaN                NaN                             NaN
# AT_018           NaN                NaN                             NaN
# AT_019           NaN                NaN                             NaN
# AT_022           NaN                NaN                             NaN
# AT_023           NaN                NaN                             NaN
# AT_028           NaN                NaN                             NaN
# AT_030           NaN                NaN                  Deal 1 damage.
# AT_032           NaN                NaN                             NaN
# AT_035t          NaN                NaN                             NaN
# AT_036           NaN                NaN                             NaN
# AT_037           NaN                NaN                             NaN
# AT_038           NaN                NaN                             NaN
# AT_038           NaN                NaN                             NaN
# AT_039           NaN                NaN                             NaN
# AT_039e          NaN                NaN                             NaN
# AT_040           NaN                NaN                             NaN
# AT_042           NaN                NaN                             NaN
# AT_042t          NaN                NaN                             NaN
# AT_042t2         NaN                NaN                             NaN
# AT_045           NaN                NaN                             NaN
# AT_046           NaN                NaN                             NaN
# AT_047           NaN                NaN                             NaN
# AT_049           NaN                NaN                             NaN
# AT_050           NaN                NaN                             NaN
# AT_054           NaN                NaN                             NaN
# AT_057           NaN                NaN  Grant <b>Immune</b> this turn.
# AT_057o          NaN                NaN                             NaN
# AT_058           NaN                NaN                             NaN
# AT_059           NaN                NaN                             NaN
# AT_060           NaN                NaN                             NaN
# AT_061e          NaN                NaN                             NaN
# AT_065           NaN                NaN                             NaN
# AT_066           NaN                NaN                             NaN
# AT_069           NaN                NaN             Grant <b>Taunt</b>.
# AT_069           NaN                NaN             Grant <b>Taunt</b>.
# AT_070           NaN                NaN                             NaN
# AT_071           NaN                NaN                             NaN
# AT_072           NaN                NaN                             NaN
# AT_073           NaN                NaN                             NaN
# AT_075           NaN                NaN                             NaN
# AT_076           NaN                NaN                             NaN
# AT_077           NaN                NaN                             NaN
#
#          faction  durability              mechanic
# card_id
# AT_002       NaN         NaN                SECRET
# AT_005t      NaN         NaN                CHARGE
# AT_006       NaN         NaN               INSPIRE
# AT_007       NaN         NaN             BATTLECRY
# AT_009       NaN         NaN           DEATHRATTLE
# AT_010       NaN         NaN             BATTLECRY
# AT_011e      NaN         NaN                  AURA
# AT_012       NaN         NaN               INSPIRE
# AT_017       NaN         NaN             BATTLECRY
# AT_018       NaN         NaN               INSPIRE
# AT_019       NaN         NaN           DEATHRATTLE
# AT_022       NaN         NaN  InvisibleDeathrattle
# AT_023       NaN         NaN               INSPIRE
# AT_028       NaN         NaN                 COMBO
# AT_030       NaN         NaN                 COMBO
# AT_032       NaN         NaN             BATTLECRY
# AT_035t      NaN         NaN               TOPDECK
# AT_036       NaN         NaN           DEATHRATTLE
# AT_037       NaN         NaN            CHOOSE_ONE
# AT_038       NaN         NaN             BATTLECRY
# AT_038       NaN         NaN           DEATHRATTLE
# AT_039       NaN         NaN               INSPIRE
# AT_039e      NaN         NaN   TAG_ONE_TURN_EFFECT
# AT_040       NaN         NaN             BATTLECRY
# AT_042       NaN         NaN            CHOOSE_ONE
# AT_042t      NaN         NaN                CHARGE
# AT_042t2     NaN         NaN               STEALTH
# AT_045       NaN         NaN                  AURA
# AT_046       NaN         NaN             BATTLECRY
# AT_047       NaN         NaN             BATTLECRY
# AT_049       NaN         NaN               INSPIRE
# AT_050       NaN         4.0           DEATHRATTLE
# AT_054       NaN         NaN             BATTLECRY
# AT_057       NaN         NaN             BATTLECRY
# AT_057o      NaN         NaN   TAG_ONE_TURN_EFFECT
# AT_058       NaN         NaN             BATTLECRY
# AT_059       NaN         NaN               INSPIRE
# AT_060       NaN         NaN                SECRET
# AT_061e      NaN         NaN   TAG_ONE_TURN_EFFECT
# AT_065       NaN         2.0             BATTLECRY
# AT_066       NaN         NaN               INSPIRE
# AT_069       NaN         NaN             BATTLECRY
# AT_069       NaN         NaN                 TAUNT
# AT_070       NaN         NaN                CHARGE
# AT_071       NaN         NaN             BATTLECRY
# AT_072       NaN         NaN             BATTLECRY
# AT_073       NaN         NaN                SECRET
# AT_075       NaN         NaN                  AURA
# AT_076       NaN         NaN               INSPIRE
# AT_077       NaN         2.0             BATTLECRY

# %% [markdown]
# Examine the output from the cell above and compare it to the original output of both the `cards_df` and `mechanics_df` DataFrame heads you displayed earlier.  Notice how this now combines the columns from both?
#
# **_Question_**
#
# If you inspect the original `cards_df` DataFrame, you'll notice that it contains  2,819 records.  The result of our inner join, `cards_with_mechanics_df`, contains only 1079 rows.  Why?
#
# Write your answer below this line:
# ________________________________________________________________________________
#
# Only the card_id index values that are in BOTH DataFrames are included because of the join type.

# %% [markdown]
# ## Other Types of Joins
#
# By default, the `.join()` method performs a left join if no parameter is passed in for `how=`.  In the cell below, perform a **_Left Join_** of `cards_with_mechanics_df` and `play_requirements_df`, with `cards_with_mechanics_df` as the left table.
#
# Then, display `left_join_df` to inspect our results.

# %%
left_join_df = cards_with_mechanics_df.join(play_requirements_df, how='left')
# Out:
#                 play_requirement  value
# card_id
# AT_069   REQ_TARGET_IF_AVAILABLE      0
# AT_069         REQ_MINION_TARGET      0

# %% [markdown]
# Note that the results of this sort of join are dependent upon the position of each table--if you were to make `cards_with_mechanics_df` the right table and `play_requirements_df` the left table and then perform a **_Right Join_**, our results would be the same.
#
# **_Question:_**
#
# Describe what was included from each table in this join.
#
# Write your answer below this line:
# ________________________________________________________________________________
#
# All of the data from cards_with_mechanics_df was included.  Two additional columns were added ('play_requirement' and 'value').  Where there are duplicate indexes (card_id) in the left df, it looks like it creates additional copies, so the joined df is larger than the original.

# %% [markdown]
# #### Outer Joins
#
# In the cell below, perform an outer join between `cards_df` and `dust_df`. Since these tables contain columns with the same name, we'll need to specify a suffix for at least one of them, so that the column can be renamed to avoid a naming collision.
#
# During this join, set the `rsuffix` parameter to `_dust`

# %%
outer_join_df = cards_df.join(dust_df, how='outer', rsuffix="_dust")
outer_join_df
# Out:
#         player_class    type         name      set  \
# card_id
# AT_001          MAGE   SPELL  Flame Lance      TGT
# AT_001          MAGE   SPELL  Flame Lance      TGT
# AT_001          MAGE   SPELL  Flame Lance      TGT
# AT_001          MAGE   SPELL  Flame Lance      TGT
# AT_002          MAGE   SPELL       Effigy      TGT
# ...              ...     ...          ...      ...
# tt_010          MAGE   SPELL  Spellbender  EXPERT1
# tt_010a         MAGE  MINION  Spellbender  EXPERT1
# tt_010a         MAGE  MINION  Spellbender  EXPERT1
# tt_010a         MAGE  MINION  Spellbender  EXPERT1
# tt_010a         MAGE  MINION  Spellbender  EXPERT1
#
#                                                       text  cost  attack  \
# card_id
# AT_001                         Deal $8 damage to a minion.   5.0     NaN
# AT_001                         Deal $8 damage to a minion.   5.0     NaN
# AT_001                         Deal $8 damage to a minion.   5.0     NaN
# AT_001                         Deal $8 damage to a minion.   5.0     NaN
# AT_002   <b>Secret:</b> When a friendly minion dies, su...   3.0     NaN
# ...                                                    ...   ...     ...
# tt_010   <b>Secret:</b> When an enemy casts a spell on ...   3.0     NaN
# tt_010a                                                NaN   1.0     1.0
# tt_010a                                                NaN   1.0     1.0
# tt_010a                                                NaN   1.0     1.0
# tt_010a                                                NaN   1.0     1.0
#
#          health  rarity  collectible  \
# card_id
# AT_001      NaN  COMMON          1.0
# AT_001      NaN  COMMON          1.0
# AT_001      NaN  COMMON          1.0
# AT_001      NaN  COMMON          1.0
# AT_002      NaN    RARE          1.0
# ...         ...     ...          ...
# tt_010      NaN    EPIC          1.0
# tt_010a     3.0    EPIC          NaN
# tt_010a     3.0    EPIC          NaN
# tt_010a     3.0    EPIC          NaN
# tt_010a     3.0    EPIC          NaN
#
#                                                     flavor race how_to_earn  \
# card_id
# AT_001   It's on the rack next to ice lance, acid lance...  NaN         NaN
# AT_001   It's on the rack next to ice lance, acid lance...  NaN         NaN
# AT_001   It's on the rack next to ice lance, acid lance...  NaN         NaN
# AT_001   It's on the rack next to ice lance, acid lance...  NaN         NaN
# AT_002                                  Burning man, brah.  NaN         NaN
# ...                                                    ...  ...         ...
# tt_010   While it's fun to intercept enemy lightning bo...  NaN         NaN
# tt_010a                                                NaN  NaN         NaN
# tt_010a                                                NaN  NaN         NaN
# tt_010a                                                NaN  NaN         NaN
# tt_010a                                                NaN  NaN         NaN
#
#         how_to_earn_golden targeting_arrow_text faction  durability  \
# card_id
# AT_001                 NaN                  NaN     NaN         NaN
# AT_001                 NaN                  NaN     NaN         NaN
# AT_001                 NaN                  NaN     NaN         NaN
# AT_001                 NaN                  NaN     NaN         NaN
# AT_002                 NaN                  NaN     NaN         NaN
# ...                    ...                  ...     ...         ...
# tt_010                 NaN                  NaN     NaN         NaN
# tt_010a                NaN                  NaN     NaN         NaN
# tt_010a                NaN                  NaN     NaN         NaN
# tt_010a                NaN                  NaN     NaN         NaN
# tt_010a                NaN                  NaN     NaN         NaN
#
#                     action  cost_dust
# card_id
# AT_001     CRAFTING_NORMAL       40.0
# AT_001     CRAFTING_GOLDEN      400.0
# AT_001   DISENCHANT_NORMAL        5.0
# AT_001   DISENCHANT_GOLDEN       50.0
# AT_002     CRAFTING_NORMAL      100.0
# ...                    ...        ...
# tt_010   DISENCHANT_GOLDEN      400.0
# tt_010a    CRAFTING_NORMAL      400.0
# tt_010a    CRAFTING_GOLDEN     1600.0
# tt_010a  DISENCHANT_NORMAL      100.0
# tt_010a  DISENCHANT_GOLDEN      400.0
#
# [5849 rows x 19 columns]

# %% [markdown]
# Inspect the output above.  Note that the naming collision has been avoided by renaming the `cost` column from the right table to `cost_dust`.
#
# ## Summary
#
# In this lab, you learned how to:
#
# * Concatenate multiple DataFrames together into a single DataFrame
# * Understand and execute the various types of joins (inner, outer, left, and right joins)
